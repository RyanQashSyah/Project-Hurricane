# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
#User will need to enter correct file path for csv file
data = pd.read_csv('C:\\Users\\Ryan\\MachineLearning\\MakeItWright2019-HackAThon\\atlantic.csv')
data.head()
# Out:
#          ID                 Name      Date  Time Event Status Latitude  \
# 0  AL011851              UNNAMED  18510625     0           HU    28.0N
# 1  AL011851              UNNAMED  18510625   600           HU    28.0N
# 2  AL011851              UNNAMED  18510625  1200           HU    28.0N
# 3  AL011851              UNNAMED  18510625  1800           HU    28.1N
# 4  AL011851              UNNAMED  18510625  2100     L     HU    28.2N
#
#   Longitude  Maximum Wind  Minimum Pressure      ...       Low Wind SW  \
# 0     94.8W            80              -999      ...              -999
# 1     95.4W            80              -999      ...              -999
# 2     96.0W            80              -999      ...              -999
# 3     96.5W            80              -999      ...              -999
# 4     96.8W            80              -999      ...              -999
#
#    Low Wind NW  Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  \
# 0         -999              -999              -999              -999
# 1         -999              -999              -999              -999
# 2         -999              -999              -999              -999
# 3         -999              -999              -999              -999
# 4         -999              -999              -999              -999
#
#    Moderate Wind NW  High Wind NE  High Wind SE  High Wind SW  High Wind NW
# 0              -999          -999          -999          -999          -999
# 1              -999          -999          -999          -999          -999
# 2              -999          -999          -999          -999          -999
# 3              -999          -999          -999          -999          -999
# 4              -999          -999          -999          -999          -999
#
# [5 rows x 22 columns]

# %%
last_ten_years = data.loc[data['Date'] > 20040000, ]
last_ten_years.head()
# Out:
#              ID                 Name      Date  Time Event Status Latitude  \
# 43104  AL012004                 ALEX  20040731  1800           TD    30.3N
# 43105  AL012004                 ALEX  20040801     0           TD    31.0N
# 43106  AL012004                 ALEX  20040801   600           TD    31.5N
# 43107  AL012004                 ALEX  20040801  1200           TD    31.6N
# 43108  AL012004                 ALEX  20040801  1800           TS    31.6N
#
#       Longitude  Maximum Wind  Minimum Pressure      ...       Low Wind SW  \
# 43104     78.3W            25              1010      ...                 0
# 43105     78.8W            25              1009      ...                 0
# 43106     79.0W            25              1009      ...                 0
# 43107     79.1W            30              1009      ...                 0
# 43108     79.2W            35              1009      ...                50
#
#        Low Wind NW  Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  \
# 43104            0                 0                 0                 0
# 43105            0                 0                 0                 0
# 43106            0                 0                 0                 0
# 43107            0                 0                 0                 0
# 43108            0                 0                 0                 0
#
#        Moderate Wind NW  High Wind NE  High Wind SE  High Wind SW  \
# 43104                 0             0             0             0
# 43105                 0             0             0             0
# 43106                 0             0             0             0
# 43107                 0             0             0             0
# 43108                 0             0             0             0
#
#        High Wind NW
# 43104             0
# 43105             0
# 43106             0
# 43107             0
# 43108             0
#
# [5 rows x 22 columns]
